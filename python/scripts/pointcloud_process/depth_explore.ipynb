# %%
FILE_ROOT = "/mnt/e/Workspace/CathederTelesurgery/Data/RosDump/2024-0924"
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
sample=np.load(f"{FILE_ROOT}/Depth/0.npy")
plt.imshow(sample)
