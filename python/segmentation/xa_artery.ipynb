# %%
FIELD_DATA_ROOT = "/mnt/w/Sync/Projects/Telesurgery/Data/Field Data/2023_11_10"
SAMPLE_IMAGE = "MARTIN_RHE-ANNE_A__784333792/NEURO_20231110_131032_406000/NEURO_DSA_0002/MARTIN_RHE-ANNE_A_.XA.NEURO.0002.0002.2023.11.10.14.32.44.921504.87486654.IMA"

# %%
import os
import SimpleITK as sitk
import numpy as np
import matplotlib.pyplot as plt

# %%
sample_image = sitk.ReadImage(os.path.join(FIELD_DATA_ROOT, SAMPLE_IMAGE))

# %%
plt.imshow(sitk.GetArrayFromImage(sample_image)[1], cmap='gray')

# %%
# Cardio
